# %%
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns 

sns.set_style(style="whitegrid")

# %%
df_pgmn = pd.DataFrame()
df_petz = pd.DataFrame()
df_pcar = pd.DataFrame()
df_assaf = pd.DataFrame()

# %%
df_pgmn["Ano"]= [2022, 2023, 2024]
df_petz["Ano"]= [2022, 2023, 2024]
df_pcar["Ano"]= [2022, 2023, 2024]
df_assaf["Ano"]= [2022, 2023, 2024]

df_pgmn["Empresa"]= "Pague Menos"
df_petz["Empresa"]= "Petz"
df_pcar["Empresa"]= "Pão de Açúcar"

# %%
df_pgmn["CCL"]= [1334111, 1338228, 1258399]
df_pgmn["NIG"]= [2201278.89, 1830200.40, 1707088.97]
df_pgmn["ILS"]= [0.3743, 0.4515, 0.3712]
df_pgmn["CO"]= [201.71, 167.54, 164.35]
df_pgmn["CF"]= [162.08, 130.83, 129.16]
df_pgmn["DivLiq/PL"]= [0.6017, 0.4499, 0.4655]
df_pgmn["Quantidade da Dívida"]= [0.4017, 0.3807, 0.3422]
df_pgmn["Qualidade da Dívida"]= [0.3005, 0.2631, 0.2611]
df_pgmn["WACC"]= [0.1422,0.1304,0.1302]
df_pgmn["MgLíq"]= [0.0287,0.0000,0.0082]
df_pgmn["ROA"]= [0.0307,0.0000,0.0115]
df_pgmn["ROE"]= [0.1129,0.0001,0.0380]
df_pgmn["ROI"]= [0.1076,0.0636,0.0917]
df_pgmn["Giro"]= [1.0688,1.2463,1.4072]
df_pgmn["PMRV"]= [26.90, 25.10, 23.98 ]
df_pgmn["PMPC"]= [39.62, 36.72, 35.19 ]

df_petz["CCL"]= [393957, 661757, 565334]
df_petz["ILS"]= [0.8968, 1.2331, 1.0981]
df_petz["NIG"]= [351103.75,  333913.93,  367297.26]
df_petz["CO"]= [145.55 , 135.29 , 138.51 ]
df_petz["CF"]= [65.90 , 57.76 , 59.56 ]
df_petz["DivLiq/PL"]= [-0.0393, 0.2092, 0.2352]
df_petz["Quantidade da Dívida"]= [0.0579, 0.1938, 0.2196]
df_petz["Qualidade da Dívida"]= [0.7628, 0.1082, 0.1350]
df_petz["WACC"]= [0.1475, 0.1296, 0.1297]
df_petz["MgLíq"]= [0.0178, 0.0052, -0.0129]
df_petz["ROA"]= [0.0139, 0.0041, -0.0110]
df_petz["ROE"]= [0.0275, 0.0090, -0.0257]
df_petz["ROI"]= [0.0458, 0.0377, 0.0195]
df_petz["Giro"]= [0.7772,0.7942,0.8529]
df_petz["PMRV"]= [41.70, 41.33, 41.89 ]
df_petz["PMPC"]= [79.64, 77.53, 78.94 ]

df_pcar["CCL"]=[12100080, 1388473, -244897]
df_pcar["ILS"]= [1.4939, 0.8949, 0.6454]
df_pcar["NIG"]= [-755415.62, -1186299.63, -1342850.87]
df_pcar["CO"]= [71.04, 59.40, 61.96]
df_pcar["CF"]= [51.80, 45.11, 49.93]
df_pcar["DivLiq/PL"]= [0.1538, 0.4877, 0.4818]
df_pcar["Quantidade da Dívida"]= [0.2992, 0.5276, 0.5795]
df_pcar["Qualidade da Dívida"]= [0.1707, 0.1843, 0.2099]
df_pcar["WACC"]= [0.1438, 0.1310, 0.1312]
df_pcar["MgLíq"]= [-0.0099, -0.1180, -0.1281]
df_pcar["ROA"]= [-0.0039, -0.1030, -0.1222]
df_pcar["ROE"]= [-0.0149, -0.4815, -0.8226]
df_pcar["ROI"]= [-0.0325, 0.0447, -0.0625]
df_pcar["Giro"]= [0.3951, 0.8730, 0.9537]
df_pcar["PMRV"]= [14.47, 10.72, 8.72 ]
df_pcar["PMPC"]= [19.25, 14.29, 12.03 ]



df_assaf["ILS"]= [0.8400, 0.6800, 0.6800]
df_assaf["DivLiq/PL"]= [0.7333, 0.9334, 0.9334]
df_assaf["WACC"]= [0.1142, 0.1075, 0.1075]
df_assaf["MgLíq"]= [0.0059, -0.0323, -0.0323]
df_assaf["ROA"]= [0.0057, -0.0318, -0.0318]
df_assaf["ROE"]= [-0.1266, -0.2683, -0.2683]
df_assaf["Giro"] = [0.9600, 0.9854, 0.9854]

# %%
df= pd.concat([df_pgmn, df_petz, df_pcar], ignore_index=True)

# %%
ILS.plot([2022,2023,2024],[1,1,1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ILS.plot([2022,2023,2024],[1,1,1])
#       2 plt.show()
#
# NameError: name 'ILS' is not defined

# %%
indices_assaf = {
    "ILS" : "Índice de Liquidez Seca (ILS)",
    "DivLiq/PL": "Divida Líquida/Patrimônio Líquido",
    "WACC": "Custo Médio Ponderado de Capital (WACC)",
    "MgLíq": "Margem Líquida",
    "ROA": "Retorno sobre Ativos (ROA)",
    "ROE": "Retorno sobre Patrimônio Líquido (ROE)",
    "Giro": "Giro do Ativo"
}

indices_perc= {
    "Quantidade da Dívida": "Quantidade da Dívida",
    "Qualidade da Dívida": "Qualidade da Dívida",
    "ROI": "Retorno sobre Investimento (ROI)",
}

indices_company = {
       "CCL": "Capital de Giro Líquido",
    "NIG": "Necessidade de Investimento em Giro",
}

indice_days = {
        "CO": "Ciclo Operacional",
    "CF": "Ciclo Financeiro",
}

# %%
for indice_name, indice_desc in indices_assaf.items():
    fig, ax = plt.subplots(figsize=(10, 6))
    sns.barplot(df, x="Ano", y=indice_name, hue="Empresa", palette="Dark2", ax=ax)
    ax.plot(df_assaf[indice_name], color="#801200", marker="o", label="Instituto Assaf")
    plt.legend()
    plt.title(f"{indice_desc} - 2022 a 2024")
    plt.figtext(0.5, 0.01, "Fonte: Economatica. Elaboração do autor", ha="center", fontsize=10)
    plt.savefig(f"{indice_name.replace("/","_")}.png")

# %%
for indice_name, indice_desc in indices_perc.items():
    fig, ax = plt.subplots(figsize=(10, 6))
    sns.barplot(df, x="Ano", y=indice_name, hue="Empresa", palette="Dark2", ax=ax)
    plt.legend()
    plt.title(f"{indice_desc} - 2022 a 2024")
    plt.figtext(0.5, 0.01, "Fonte: Economatica. Elaboração do autor", ha="center", fontsize=10)
    plt.savefig(f"{indice_name.replace("/","_")}.png")

# %%
df2 = df[["Ano", "Empresa", "CCL", "NIG"]].set_index(["Ano", "Empresa"]).stack().reset_index()
df2 = df2.rename(columns={"level_2": "Indice", 0: "Valor (R$ milhões)"})
df2["Valor (R$ milhões)"] /= 1e6

# %%
g = sns.catplot(df2, x="Ano", y="Valor (R$ milhões)", hue="Indice", col="Empresa", palette="Dark2", kind="bar", height=6, aspect=0.75)
g.set_titles("{col_name}")
plt.figtext(0.5, 0.01, "Fonte: Economatica. Elaboração do autor", ha="center", fontsize=10)
g.figure.suptitle("Capital de Giro Líquido e Necessidade de Investimento em Giro - 2022 a 2024", y=1.05)
plt.savefig(f"CCL e NIG.png")

# %%
df3 = df[["Ano", "Empresa", "CO", "CF"]].set_index(["Ano", "Empresa"]).stack().reset_index()
df3 = df3.rename(columns={"level_2": "Indice", 0: "Dias"})

# %%
g = sns.catplot(df3, x="Ano", y="Dias", hue="Indice", col="Empresa", palette="Dark2", kind="bar", height=6, aspect=0.75)
g.set_titles("{col_name}")
plt.figtext(0.5, 0.01, "Fonte: Economatica. Elaboração do autor", ha="center", fontsize=10)
g.figure.suptitle("Ciclo Operacional e Ciclo Financeiro - 2022 a 2024", y=1.05)
plt.savefig(f"CO e CF.png")

# %%
df4 = df[["Ano", "Empresa", "PMRV", "PMPC"]].set_index(["Ano", "Empresa"]).stack().reset_index()
df4 = df4.rename(columns={"level_2": "Indice", 0: "Dias"})

# %%
g = sns.catplot(df4, x="Ano", y="Dias", hue="Indice", col="Empresa", palette="Dark2", kind="bar", height=6, aspect=0.75)
g.set_titles("{col_name}")
plt.figtext(0.5, 0.01, "Fonte: Economatica. Elaboração do autor", ha="center", fontsize=10)
g.figure.suptitle("Prazo médio de recebimento de vendar e pagamento de fornecedores - 2022 a 2024", y=1.05)
plt.savefig(f"PMRV e PMPC.png")
